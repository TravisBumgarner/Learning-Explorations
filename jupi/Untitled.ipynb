# %%
import pandas as pd

# %%
budgets = pd.read_csv("./budget.csv")

# %%
budgets.head()
# Out:
#    Fiscal Year             Service         Department        Division  \
# 0         2017       Public Safety             Police          Patrol
# 1         2017  General Government         City Clerk  Administration
# 2         2017       Public Safety  Animal Commission  Administration
# 3         2017       Public Safety  Animal Commission  Administration
# 4         2017       Public Safety  Animal Commission  Administration
#
#   Position Number               Job Title  Total Salary
# 0        P465-081          Police Officer         74558
# 1        C107-709         Principal Clerk         48788
# 2        M137-701   Dir/Animal Commission         92359
# 3        A209-702  Animal Control Officer         60197
# 4        A209-701  Animal Control Officer         60197

# %%
columns = budgets.columns

# %%
columns
# Out:
# Index(['Fiscal Year', 'Service', 'Department', 'Division', 'Position Number',
#        'Job Title', 'Total Salary'],
#       dtype='object')

# %%
budgets.sort_values('Total Salary', ascending=False)
# Out:
#       Fiscal Year                          Service           Department  \
# 2228         2018                    Public Safety                 Fire
# 2356         2018                    Public Safety               Police
# 2357         2018                    Public Safety               Police
# 161          2017               General Government            Executive
# 5272         2020               General Government            Executive
# ...           ...                              ...                  ...
# 762          2017  Human Resources and Development       Human Services
# 1862         2018               General Government                Mayor
# 1728         2018               General Government  Election Commission
# 3492         2019               General Government  Election Commission
# 5329         2020               General Government              Finance
#
#                                  Division Position Number  \
# ...
